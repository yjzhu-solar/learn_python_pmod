# %%
import eispac
import matplotlib.pyplot as plt

# %%
# load the datacube 

eis_data = eispac.read_cube(
    "/home/yjzhu/Solar/learn_python_pmod/data/eis_20221025_002341.data.h5",
window=195.119)
# Out:
# Data file,
#    /home/yjzhu/Solar/learn_python_pmod/data/eis_20221025_002341.data.h5
# Header file,
#    /home/yjzhu/Solar/learn_python_pmod/data/eis_20221025_002341.head.h5
# Found a wavelength 195.12 [Angstroms] in window 8

# %%
eis_data.meta.keys()
# Out:
# dict_keys(['filename_data', 'filename_head', 'wininfo', 'iwin', 'iwin_str', 'index', 'pointing', 'wave', 'radcal', 'slit_width', 'slit_width_units', 'ccd_offset', 'wave_corr', 'wave_corr_t', 'wave_corr_tilt', 'date_obs', 'date_obs_format', 'duration', 'duration_units', 'mod_index', 'aspect', 'aspect_ratio', 'extent_arcsec', 'notes'])

# %%
eis_data.meta["wininfo"]
# Out:
# rec.array([( 0, 'Fe XI 180.400', 180.03426, 180.72559, 32,  661),
#            ( 1, 'Ca XV 182.100', 181.75139, 182.44266, 32,  738),
#            ( 2, 'Fe X 184.330', 183.9812 , 184.67238, 32,  838),
#            ( 3, 'Fe VIII 185.210', 184.93993, 185.45273, 24,  881),
#            ( 4, 'Fe XII 186.750', 186.3891 , 187.0802 , 32,  946),
#            ( 5, 'Fe XI 188.400', 187.86046, 188.90817, 48, 1012),
#            ( 6, 'Ca XVII 192.470', 191.85039, 193.07619, 56, 1191),
#            ( 7, 'Ca XIV 194.100', 193.65562, 194.52475, 40, 1272),
#            ( 8, 'Fe XII 195.120', 194.85902, 195.37155, 24, 1326),
#            ( 9, 'Fe IX 197.860', 197.59981, 198.11227, 24, 1449),
#            (10, 'Ca XV 201.050', 200.78578, 201.29816, 24, 1592),
#            (11, 'Fe XIII 202.040', 201.76598, 202.27834, 24, 1636),
#            (12, 'Fe XIII 203.830', 203.5703 , 204.0826 , 24, 1717),
#            (13, 'Ca XVI 208.500', 208.13603, 208.82637, 32, 1922),
# ...

# %%
fe12_tmplt = eispac.read_template("../data/fe_12_195_119.2c.template.h5")

# %%
fe12_tmplt
# Out:
# --- EISFitTemplate SUMMARY ---
# filename_temp: ../data/fe_12_195_119.2c.template.h5
# n_gauss: 2
# n_poly: 1
# line_ids: ['Fe XII 195.119' 'Fe XII 195.179']
# wmin, wmax: 194.9600067138672, 195.25
#
# --- PARAMETER CONSTRAINTS ---
#    *            Value   Fixed     Limited              Limits                Tied
#   p[0]     57514.6647       0     1     0       0.0000       0.0000
#   p[1]       195.1179       0     1     1     195.0778     195.1581
#   p[2]         0.0289       0     1     1       0.0191       0.0510
#   p[3]      8013.4013       0     1     0       0.0000       0.0000
#   p[4]       195.1779       0     1     1     195.1378     195.2181          p[1]+0.06
#   p[5]         0.0289       0     1     1       0.0191       0.0510          p[2]
#   p[6]       664.3349       0     0     0       0.0000       0.0000
